# %% [markdown]
# # **PYTHON TUTORIAL

# %% [markdown]
# ### (from scratch)
#
# ## *data types

# %%
10%2

#gives remainder
# Out:
# 0

# %%
10/3  #giving quotient as output
# Out:
# 3.3333333333333335

# %%
type(3)
# Out:
# int

# %%
type(3.45)
# Out:
# float

# %%
type("manikumar")
# Out:
# str

# %%
type("10")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type("false")
# Out:
# str

# %%
first_name="Mani Kumar"
last_name="Donepudi"

# %%
print("my first name is {} and my second name is {}".format(first_name,last_name)) #here we are using dictionary
# Out:
# my first name is Mani Kumar and my second name is Donepudi

# %%
print("my first name is {} and my last name is {}".format(last_name,first_name*4))
# Out:
# my first name is Donepudi and my last name is Mani KumarMani KumarMani KumarMani Kumar

# %%
print("my name is {}".format(first_name + last_name))
# Out:
# my name is Mani KumarDonepudi

# %%
print("my first name is {first} and my last name is {second}".format(first=first_name*3,second=last_name))
# Out:
# my first name is Mani KumarMani KumarMani Kumar and my last name is Donepudi

# %%
len("mani kumar") #counting the spacings also
# Out:
# 10

# %%
len("10")
# Out:
# 2

# %%
a=len([1,2,3,4,5,"manikumar","789"])

# %%
type(a)
# Out:
# int

# %%
b=[1,2,3,4,5,6,7]

# %%
type(b)
# Out:
# list

# %%
c=(12,1,2,12,56)

# %%
type(c)
# Out:
# tuple

# %% [markdown]
# ## *insert will take the positional indexing also

# %%
b.insert(3,45)

# %%
b
# Out:
# [1, 2, 3, 45, 4, 5, 6, 7]

# %% [markdown]
# ## *tuple has only 2 indexing and counting

# %%
c.count(1)
# Out:
# 1

# %%
c.index(1)
# Out:
# 1
