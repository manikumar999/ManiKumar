# %% [markdown]
# # *why we use only PYTHON when we have other programming languages

# %% [markdown]
# # 1.It is very easy to use

# %% [markdown]
# # 2.Coding lines are also very less when compared to other programming languages

# %% [markdown]
# # 3. Python contains Multiple Libraries and Multiple Frame Works

# %% [markdown]
# # *more over Python is a open source programming languages

# %% [markdown]
# # *Developers can use these libraries and frame-works and completes works very fast

# %% [markdown]
# # FRAME-WORK:- it provides a foundation on which python developers can write programs related to specific platform
#
# # *this plat-form can be used for developing different software applications
#
# # * Some of the Frame Works are Keras,TensorFlow PyTorch use in DEEP-LEARNING programms

# %% [markdown]
# # LIBRARIES:- some of the imporatant libraries are NUMPY,PANDAS,
# # *matplotlib and seaborn libraries for visualization
# # * most important library is Scikit-Learn . It contain all types of machine learning algorithms

# %% [markdown]
# # *** Python is also used in
# # Web based applications
# # web scrapping

# %% [markdown]
# # 4. Python contains Community and corporate Support. This means many developers are using python skills to increase machine-learning knowledge and used in deep-learning projects also

# %% [markdown]
# # 5. all top most companies are using this for various applications

# %% [markdown]
# # *Google for Google assistance
# # *facebook for Friend recommendation system
# # *Amazon for Alexa
# # *Neflix for movie recommendation System............. and many other

# %% [markdown]
# # ***********  more over we having so much online stuff related topython
