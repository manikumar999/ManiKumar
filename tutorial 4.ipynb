# %% [markdown]
# # ******sets
# # * rept by {} only  same as "dict" but it contain elements in it but dict contain some other

# %% [markdown]
# # * it is not having any duplicate elements(repetative)
# # * it does not support indexing

# %%
set_type=set()

# %%
type(set_type)
# Out:
# set

# %%
print(type(set_type))
# Out:
# <class 'set'>

# %%
set_type={1,2,3,4,5}

# %%
type(set_type)
# Out:
# set

# %%
set2={2,3,4,5,6}

# %%
set_type.add(25)

# %%
set_type
# Out:
# {1, 2, 3, 4, 5, 25}

# %%
set_type.difference(set2)
# Out:
# {1, 25}

# %%
set2.difference(set_type) #elements not present in set_type compared to set2 will be given as new set
# Out:
# {6}

# %%
set_type.discard(25)

# %%
set_type
# Out:
# {1, 2, 3, 4, 5}

# %%
set_type.intersection(set2)
# Out:
# {2, 3, 4, 5}

# %%
set_type.intersection_update(set2) # set_type will be updated as a new set

# %%
set_type
# Out:
# {2, 3, 4, 5}

# %%
set2
# Out:
# {2, 3, 4, 5, 6}

# %%
set_type.symmetric_difference(set2)
# Out:
# {6}

# %%
set2.symmetric_difference(set_type)
# Out:
# {6}

# %%
set_type
# Out:
# {2, 3, 4, 5}

# %%
set2
# Out:
# {2, 3, 4, 5, 6}

# %%
set_type.difference(set2)
# Out:
# set()

# %%
set2.difference(set_type)
# Out:
# {6}

# %%
a={1,2,3,4}

# %%
type(a)
# Out:
# set

# %% [markdown]
# # *Dictionary
# # * does not support indexing only sub-setting

# %%
ranking={"rank1":"syed","rank2":"nikhil","rank3":"manikumar"}

# %%
ranking
# Out:
# {'rank1': 'syed', 'rank2': 'nikhil', 'rank3': 'manikumar'}

# %%
ranking["rank1"]
# Out:
# 'syed'

# %%
for i in ranking:
    print(i)
# Out:
# rank1
# rank2
# rank3

# %%
for i in ranking.values():
    print(i)
# Out:
# syed
# nikhil
# manikumar

# %%
for i in ranking.items():
    print(i)
# Out:
# ('rank1', 'syed')
# ('rank2', 'nikhil')
# ('rank3', 'manikumar')

# %%
ranking["rank4"]="saikrishna"

# %%
ranking
# Out:
# {'rank1': 'syed',
#  'rank2': 'nikhil',
#  'rank3': 'manikumar',
#  'rank4': 'saikrishna'}

# %%
ranking["rank2"]="divya"

# %%
ranking
# Out:
# {'rank1': 'syed',
#  'rank2': 'divya',
#  'rank3': 'manikumar',
#  'rank4': 'saikrishna'}

# %% [markdown]
# # *NESTED dictionary

# %%
institute1={"syed":"insofe"}
institute2={"divya":"insofe"}
institute3={"manikumar":"insofe"}
institute4={"saikrishna":"insofe"}

list={"rank1":institute1,"rank2":institute2,"rank3":institute3,"rank4":institute4}

# %%
list
# Out:
# {'rank1': {'syed': 'insofe'},
#  'rank2': {'divya': 'insofe'},
#  'rank3': {'manikumar': 'insofe'},
#  'rank4': {'saikrishna': 'insofe'}}

# %%
print(list)
# Out:
# {'rank1': {'syed': 'insofe'}, 'rank2': {'divya': 'insofe'}, 'rank3': {'manikumar': 'insofe'}, 'rank4': {'saikrishna': 'insofe'}}

# %%
list["rank1"]
# Out:
# {'syed': 'insofe'}

# %%
list["rank1"]["syed"]
# Out:
# 'insofe'

# %% [markdown]
# # *tuples

# %%
my_tuple=tuple()

# %%
type(my_tuple)
# Out:
# tuple
