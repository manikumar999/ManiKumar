# %% [markdown]
# # **booleaN

# %% [markdown]
# # * if we want to add any thing at the end of the list we use append
# # * if we want  to insert in a particular position use "insert"
#
# # * if we dont list in a list just want to continue in the list use "extend"

# %% [markdown]
# # * pop() will remove last element in the list
# # * pop(1) will remove 1st index element in thelist

# %% [markdown]
# # * count( any number)  will count number of time the number occurs in the list
# # * index(1) will tell in which index the number "1" is present .... we can give min and max index values also

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
my_str="mani kumar"

# %%
print(my_str.isalnum())
# Out:
# False

# %%
my_str.capitalize()
# Out:
# 'Mani kumar'

# %%
my_str
# Out:
# 'mani kumar'

# %%
my_str.casefold() #removes all special cases like german words
# Out:
# 'mani kumar'

# %%
my_str.isascii()
# Out:
# True

# %%
my_str.join(my_str1)
# Out:
# 'rmani kumaromani kumaromani kumarpmani kumaremani kumarsmani kumarh'

# %%
my_str1="roopesh"

# %%
my_str.replace(my_str,my_str1)
# Out:
# 'roopesh'

# %%
my_str.islower()
# Out:
# True

# %% [markdown]
# # boolean and logical operators

# %%
True and True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True and False
# Out:
# False

# %%
a=10
b=20

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a<=b
# Out:
# True

# %% [markdown]
# # *list

# %%
type([])
# Out:
# list

# %%
type(())
# Out:
# tuple

# %%
type({})
# Out:
# dict

# %%
a=[] #creating an empty list

# %%
type(a)
# Out:
# list

# %%
lst=list() #creating an empty list

# %%
type(lst)
# Out:
# list

# %% [markdown]
# # INDEXING

# %%
list=[1,2,3,4,5,6,"manikumar","nikhil"]

# %%
list[1]
# Out:
# 2

# %%
list[0]
# Out:
# 1

# %%
list[7]
# Out:
# 'nikhil'

# %%
list.append("roopesh")

# %%
list
# Out:
# [1, 2, 3, 4, 5, 6, 'manikumar', 'nikhil', 'roopesh']

# %%
list.clear()

# %%
list
# Out:
# []

# %%
list.copy()
# Out:
# [1, 2, 3, 4, 5, 6, 'manikumar', 'nikhil']

# %%
list.count(1)
# Out:
# 1

# %%
list.reverse()

# %%
list
# Out:
# ['nikhil', 'manikumar', 6, 5, 4, 3, 2, 1]

# %%
list[:]
# Out:
# ['nikhil', 'manikumar', 6, 5, 4, 3, 2, 1]

# %%
list[1:]
# Out:
# ['manikumar', 6, 5, 4, 3, 2, 1]

# %%
list[1:4]
# Out:
# ['manikumar', 6, 5]

# %%
list[-1]
# Out:
# 1

# %%
list[-6:]
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
list[-6:-3]
# Out:
# [6, 5, 4]

# %% [markdown]
# # *list inside a list is called nested list

# %%
list.append(["samantha","regina"])

# %%
list
# Out:
# ['nikhil', 'manikumar', 6, 5, 4, 3, 2, 1, ['samantha', 'regina']]

# %%
list.insert(3,"insofe")

# %%
list
# Out:
# ['nikhil', 'manikumar', 6, 'insofe', 5, 4, 3, 2, 1, ['samantha', 'regina']]

# %%
list3=[2,3,4,5,6,7,8]

# %%
sum(list3)
# Out:
# 35

# %%
list3.append([3,4,5])

# %%
list3
# Out:
# [2, 3, 4, 5, 6, 7, 8, [3, 4, 5]]

# %%
list3.index(3)
# Out:
# 1

# %%
list3.extend([1,2,3])

# %%
list3
# Out:
# [2, 3, 4, 5, 6, 7, 8, [3, 4, 5], 1, 2, 3]

# %%
list3.sort
# Out:
# <function list.sort(*, key=None, reverse=False)>

# %%
list3
# Out:
# [2, 3, 4, 5, 6, 7, 8, [3, 4, 5], 1, 2, 3]

# %%
list3.pop(5)
# Out:
# 7

# %%
list3.count(1)
# Out:
# 1

# %%
list3*2
# Out:
# [2, 3, 4, 5, 6, 8, [3, 4, 5], 1, 2, 2, 3, 4, 5, 6, 8, [3, 4, 5], 1, 2]

# %%
list
# Out:
# ['nikhil', 'manikumar', 6, 'insofe', 5, 4, 3, 2, 1, ['samantha', 'regina']]
